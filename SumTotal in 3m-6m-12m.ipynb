# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('modified_file.csv')

# Remove the 'w' character from the 'Source' column
df['Source'] = df['Source'].str.replace('w', '')

# Save the updated DataFrame to a new CSV file
df.to_csv('w.csv', index=False)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('w.csv')

# Extract year and month from the "time" column
df['year'] = df['time'].apply(lambda x: int(str(x)[:1]) + 2020 if str(x)[:1].isdigit() else None)
df['month'] = df['time'].apply(lambda x: int(str(x)[1:3]) if str(x)[2:3].isdigit() else None)

# Save the updated DataFrame to a new CSV file
df.to_csv('dateee.csv', index=False)

# %%
import csv

# Read the original CSV file
with open('dateee.csv', 'r') as input_file:
    reader = csv.DictReader(input_file)
    transactions = list(reader)

# Prepare the headers for the output CSV file
fieldnames = ['person', 'amount', 'year', 'month', 'num_transactions', 'total_amount']

# Write the data to the output CSV file
with open('sum-outfromsource-3months.csv', 'w', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate through each transaction
    for i, transaction in enumerate(transactions):
        person = transaction['person']
        amount = float(transaction['amount'])
        year = transaction['year']
        month = transaction['month']

        # Filter transactions within the last three months (excluding the current month)
        if int(month) == 1:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 10 )
            ]
        elif int(month) == 2:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 11 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 3 and int(t['month']) < int(month)))
            ]
        elif int(month) == 3:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 12 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 3 and int(t['month']) < int(month)))
            ]
        else:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 3 and int(t['month']) < int(month))
            ]

        num_transactions = len(filtered_transactions)
        total_amount = sum(float(t['amount']) for t in filtered_transactions)

        # Write the row to the output CSV file
        writer.writerow({
            'person': person,
            'amount': amount,
            'year': year,
            'month': month,
            'num_transactions': num_transactions,
            'total_amount': total_amount
        })

# %%
import csv

# Read the original CSV file
with open('date.csv', 'r') as input_file:
    reader = csv.DictReader(input_file)
    transactions = list(reader)

# Prepare the headers for the output CSV file
fieldnames = ['person', 'amount', 'year', 'month', 'num_transactions', 'total_amount']

# Write the data to the output CSV file
with open('sum-outfromsource-6months.csv', 'w', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate through each transaction
    for i, transaction in enumerate(transactions):
        person = transaction['person']
        amount = float(transaction['amount'])
        year = transaction['year']
        month = transaction['month']

        # Filter transactions within the last three months (excluding the current month)
        if int(month) == 1:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 7 )
            ]
        elif int(month) == 2:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 8 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 3:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 9 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 4:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 10 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 5:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 11 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 6:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 12 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        else:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month))
            ]

        num_transactions = len(filtered_transactions)
        total_amount = sum(float(t['amount']) for t in filtered_transactions)

        # Write the row to the output CSV file
        writer.writerow({
            'person': person,
            'amount': amount,
            'year': year,
            'month': month,
            'num_transactions': num_transactions,
            'total_amount': total_amount
        })

# %%
import csv

# Read the original CSV file
with open('date.csv', 'r') as input_file:
    reader = csv.DictReader(input_file)
    transactions = list(reader)

# Prepare the headers for the output CSV file
fieldnames = ['person', 'amount', 'year', 'month', 'num_transactions', 'total_amount']

# Write the data to the output CSV file
with open('sum-outfromsource-12months.csv', 'w', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate through each transaction
    for i, transaction in enumerate(transactions):
        person = transaction['person']
        amount = float(transaction['amount'])
        year = transaction['year']
        month = transaction['month']

        # Filter transactions within the last three months (excluding the current month)
        if int(month) == 1:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 1 )
            ]
        elif int(month) == 2:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 2 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 3:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 3 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 4:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 4 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 5:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 5 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 6:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 6 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 7:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 7 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 8:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 8 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 9:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 9 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 10:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 10 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 11:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 11 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 12:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 12 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        else:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month))
            ]

        num_transactions = len(filtered_transactions)
        total_amount = sum(float(t['amount']) for t in filtered_transactions)

        # Write the row to the output CSV file
        writer.writerow({
            'person': person,
            'amount': amount,
            'year': year,
            'month': month,
            'num_transactions': num_transactions,
            'total_amount': total_amount
        })

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('140sample-t.csv')

# Remove the 'w' character from the 'Source' column
df['Target'] = df['Target'].str.replace('w', '')

# Save the updated DataFrame to a new CSV file
df.to_csv('w-t.csv', index=False)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('w-t.csv')

# Extract year and month from the "time" column
df['year'] = df['time'].apply(lambda x: int(str(x)[:1]) + 2020 if str(x)[:1].isdigit() else None)
df['month'] = df['time'].apply(lambda x: int(str(x)[1:3]) if str(x)[2:3].isdigit() else None)

# Save the updated DataFrame to a new CSV file
df.to_csv('date-t.csv', index=False)

# %%
import csv

# Read the original CSV file
with open('date-t.csv', 'r') as input_file:
    reader = csv.DictReader(input_file)
    transactions = list(reader)

# Prepare the headers for the output CSV file
fieldnames = ['person', 'amount', 'year', 'month', 'num_transactions', 'total_amount']

# Write the data to the output CSV file
with open('sum-infromsource-3months.csv', 'w', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate through each transaction
    for i, transaction in enumerate(transactions):
        person = transaction['person']
        amount = float(transaction['amount'])
        year = transaction['year']
        month = transaction['month']

        # Filter transactions within the last three months (excluding the current month)
        if int(month) == 1:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 10 )
            ]
        elif int(month) == 2:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 11 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 3 and int(t['month']) < int(month)))
            ]
        elif int(month) == 3:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 12 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 3 and int(t['month']) < int(month)))
            ]
        else:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 3 and int(t['month']) < int(month))
            ]

        num_transactions = len(filtered_transactions)
        total_amount = sum(float(t['amount']) for t in filtered_transactions)

        # Write the row to the output CSV file
        writer.writerow({
            'person': person,
            'amount': amount,
            'year': year,
            'month': month,
            'num_transactions': num_transactions,
            'total_amount': total_amount
        })

# %%
import csv

# Read the original CSV file
with open('date-t.csv', 'r') as input_file:
    reader = csv.DictReader(input_file)
    transactions = list(reader)

# Prepare the headers for the output CSV file
fieldnames = ['person', 'amount', 'year', 'month', 'num_transactions', 'total_amount']

# Write the data to the output CSV file
with open('sum-infromsource-6months.csv', 'w', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate through each transaction
    for i, transaction in enumerate(transactions):
        person = transaction['person']
        amount = float(transaction['amount'])
        year = transaction['year']
        month = transaction['month']

        # Filter transactions within the last three months (excluding the current month)
        if int(month) == 1:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 7 )
            ]
        elif int(month) == 2:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 8 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 3:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 9 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 4:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 10 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 5:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 11 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        elif int(month) == 6:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 12 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month)))
            ]
        else:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 6 and int(t['month']) < int(month))
            ]

        num_transactions = len(filtered_transactions)
        total_amount = sum(float(t['amount']) for t in filtered_transactions)

        # Write the row to the output CSV file
        writer.writerow({
            'person': person,
            'amount': amount,
            'year': year,
            'month': month,
            'num_transactions': num_transactions,
            'total_amount': total_amount
        })

# %%
import csv

# Read the original CSV file
with open('date-t.csv', 'r') as input_file:
    reader = csv.DictReader(input_file)
    transactions = list(reader)

# Prepare the headers for the output CSV file
fieldnames = ['person', 'amount', 'year', 'month', 'num_transactions', 'total_amount']

# Write the data to the output CSV file
with open('sum-infromsource-12months.csv', 'w', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=fieldnames)
    writer.writeheader()

    # Iterate through each transaction
    for i, transaction in enumerate(transactions):
        person = transaction['person']
        amount = float(transaction['amount'])
        year = transaction['year']
        month = transaction['month']

        # Filter transactions within the last three months (excluding the current month)
        if int(month) == 1:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 1 )
            ]
        elif int(month) == 2:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 2 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 3:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 3 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 4:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) >= 4 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 5:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 5 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 6:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 6 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 7:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 7 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 8:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 8 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 9:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 9 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 10:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 10 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 11:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 11 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        elif int(month) == 12:
            filtered_transactions = [
                t for t in transactions[:i] if (t['person'] == person and int(t['year']) == int(year)-1
                and (int(t['month']) == 12 )) or(t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month)))
            ]
        else:
            filtered_transactions = [
                t for t in transactions[:i] if t['person'] == person and int(t['year']) == int(year)
                and (int(t['month']) >= int(month) - 12 and int(t['month']) < int(month))
            ]

        num_transactions = len(filtered_transactions)
        total_amount = sum(float(t['amount']) for t in filtered_transactions)

        # Write the row to the output CSV file
        writer.writerow({
            'person': person,
            'amount': amount,
            'year': year,
            'month': month,
            'num_transactions': num_transactions,
            'total_amount': total_amount
        })
